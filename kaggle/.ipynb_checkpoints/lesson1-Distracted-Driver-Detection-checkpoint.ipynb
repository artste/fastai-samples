# %% [markdown]
# # Lesson 1 - Are you a distracted driver?
# # Kaggle competition sample

# %% [markdown]
# Try to address the Synthetic Digits dataset using concepts from lesson1/v3
#
# https://www.kaggle.com/c/state-farm-distracted-driver-detection

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.vision import *

# %% [markdown]
# # Prerequisite: install kaggle api
#
# Follow instructions on https://github.com/Kaggle/kaggle-api
#
# The main steps are installing the cli ("pip install kaggle") and setting up your credentials on ~/.kaggle/kaggle.json

# %% [markdown]
# ## Download competition dataset from kaggle
#
# The following steps are valid for almost any kaggle competition.

# %%
#Prepare dataset props
competition_name='state-farm-distracted-driver-detection' # this is the kaggle dataset name
dest_folder_name='distracted-driver' # sub folder of fast.ai data folder

# %%
#Prepare params
from fastai.datasets import datapath4file
path = datapath4file(f'{(dest_folder_name)}')
dest_folder = path.as_posix()
print(dest_folder)
# Out:
# /home/ste/.fastai/data/distracted-driver

# %% [markdown]
# Call kaggle cli to download dataset and unzip it.

# %%
# Call kaggle cli to download competition
# !kaggle competitions download -c {competition_name} -p {dest_folder}

# %% [markdown]
# Take a look of what's inside...

# %%
# !ls -l {dest_folder}
# Out:
# total 4215220
# -rw-r--r--  1 ste ste     491359 apr  7  2016 driver_imgs_list.csv
# -rw-rw-r--  1 ste ste      95118 ott 23 15:19 driver_imgs_list.csv.zip
# -rw-rw-r--  1 ste ste 4292669227 ott 23 15:19 imgs.zip
# drwxrwxr-x  2 ste ste       4096 ott 26 01:54 models
# -rw-rw-r--  1 ste ste    4298269 giu 21 00:16 sample_submission.csv
# -rw-rw-r--  1 ste ste     197611 ott 23 15:08 sample_submission.csv.zip
# -rw-rw-r--  1 ste ste   11364440 ott 25 21:30 submission.csv
# -rw-rw-r--  1 ste ste    4530371 ott 26 08:39 submission.csv.gz
# drwxr-xr-x  2 ste ste    2711552 ott 23 17:16 test
# drwxr-xr-x 12 ste ste       4096 mar 29  2016 train

# %% [markdown]
# Let's unzip the needed files...

# %%
#Unzip
# !unzip -o -q {dest_folder}/driver_imgs_list.csv.zip -d {dest_folder}
# !unzip  -o -q {dest_folder}/imgs.zip -d {dest_folder}
# !unzip  -o -q {dest_folder}/sample_submission.csv.zip -d {dest_folder}

# %% [markdown]
# ## Looking at the data

# %% [markdown]
# Classes:
# * c0: safe driving
# * c1: texting - right
# * c2: talking on the phone - right
# * c3: texting - left
# * c4: talking on the phone - left
# * c5: operating the radio
# * c6: drinking
# * c7: reaching behind
# * c8: hair and makeup
# * c9: talking to passenger

# %%
description_dict = {"c0": "safe driving","c1": "texting - right","c2": "talking on the phone - right","c3": "texting - left","c4": "talking on the phone - left","c5": "operating the radio","c6": "drinking","c7": "reaching behind","c8": "hair and makeup","c9": "talking to passenger"}

# %%
#Define paths
path_train = path/'train'
path_test = path/'test'

# %%
# Training set:
print('Training set folders: ', path_train.ls())
# Out:
# training set folders:  ['c5', 'c4', 'c7', 'c8', 'c6', 'c2', 'c9', 'c1', 'c0', 'c3']

# %%
# test set:
print('Test set files count: ', len(path_test.ls()))
# Out:
# Test set files count:  79726

# %%
print('dataset rows: ' + str(len(path_test.ls())))
print('sample: ', path_test.ls()[:10])
# Out:
# dataset rows: 79726
# sample:  ['img_44563.jpg', 'img_24158.jpg', 'img_69173.jpg', 'img_21453.jpg', 'img_12083.jpg', 'img_49408.jpg', 'img_80686.jpg', 'img_9258.jpg', 'img_98345.jpg', 'img_90161.jpg']

# %% [markdown]
# ## Create DataBunch 'from_lists' and take a look

# %%
# Flat operator for list:
# Transform List[List[a]] -> List[a]
flat_list = lambda l: [item for sublist in l for item in sublist] # flat operator for list

# %%
# Create list of all files
all_files = flat_list([d.glob('*') for d in path_train.glob('*')])
np.random.shuffle(all_files) # Ensure no bias from ordering
print('Files count: ' + str(len(all_files)))
print('sample: ', all_files[:10])
files = all_files # Assign files scope to all
# Out:
# Files count: 22424
# sample:  [PosixPath('/home/ste/.fastai/data/distracted-driver/train/c7/img_68240.jpg'), PosixPath('/home/ste/.fastai/data/distracted-driver/train/c7/img_76522.jpg'), PosixPath('/home/ste/.fastai/data/distracted-driver/train/c5/img_22873.jpg'), PosixPath('/home/ste/.fastai/data/distracted-driver/train/c4/img_96966.jpg'), PosixPath('/home/ste/.fastai/data/distracted-driver/train/c8/img_90540.jpg'), PosixPath('/home/ste/.fastai/data/distracted-driver/train/c8/img_61896.jpg'), PosixPath('/home/ste/.fastai/data/distracted-driver/train/c5/img_82866.jpg'), PosixPath('/home/ste/.fastai/data/distracted-driver/train/c0/img_75961.jpg'), PosixPath('/home/ste/.fastai/data/distracted-driver/train/c8/img_72343.jpg'), PosixPath('/home/ste/.fastai/data/distracted-driver/train/c3/img_19024.jpg')]

# %% [markdown]
# **IMPORTANT**: during experimentation we take sub-sample of complete list to iterate quickly.

# %%
# Select subset for test covergence
# IMPORTANT: skip this cell in final version
import random
items_count = int(len(all_files) * .1)
files = random.sample(all_files,items_count)

print('Files count: ' + str(len(files)))

# %%
# Support function: extract class from file name
extractClass = lambda l: Path(l[l.rfind('train')+len('train')+1:]).parent.as_posix()
print(extractClass('/home/xxx/.fastai/data/distracted-driver/train/c5/img_82866.jpg'))
# Out:
# c5

# %%
# Compute labels for all files
labels = list(map(extractClass, map(Path.as_posix, files)))
print('Sample 1: ', list(labels)[:10])
print('Sample 2: ', list(labels)[-10:])
# Out:
# Sample 1:  ['c7', 'c7', 'c5', 'c4', 'c8', 'c8', 'c5', 'c0', 'c8', 'c3']
# Sample 2:  ['c2', 'c8', 'c0', 'c3', 'c3', 'c1', 'c0', 'c2', 'c2', 'c5']

# %%
# Create data augmentation:
tfms = get_transforms(flip_vert=False, do_flip=False, max_zoom=1.0) # Tune data augmentation
# NB: use 20% of train set as validation set
data = ImageDataBunch.from_lists(path=path, fnames=files, labels=labels, valid_pct=0.2, test='test', ds_tfms=tfms, size=256, bs=32)
data.normalize(imagenet_stats)

# %%
data.show_batch(rows=3, figsize=(9,9), is_train=True)

# %%
# Sort and Show classes
#data.classes.sort() # Sort in place
print('Classes: ',data.classes)
print('len: ',len(data.classes),data.c)
# Out:
# Classes:  ['c7', 'c5', 'c4', 'c8', 'c0', 'c3', 'c1', 'c2', 'c6', 'c9']
# len:  10 10

# %% [markdown]
# ## Training: resnet50

# %%
#import torch.functional
#logloss = torch.functional.F.nll_loss # Alis for log loss

# %%
learn = ConvLearner(data, models.resnet50, metrics=error_rate)
#learn = ConvLearner(data, models.resnet50, metrics=logloss)

# %% [markdown]
# ## Lr Finder

# %%
learn.lr_find()
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, max=1), HTML(value='0.00% [0/1 00:00<00:00]'))), HTML(value…

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(10, max_lr=slice(1e-3,1e-2))
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, max=10), HTML(value='0.00% [0/10 00:00<00:00]'))), HTML(val…
# Total time: 22:04
# epoch  train loss  valid loss  error_rate
# 1      0.240397    0.074954    0.021343    (02:14)
# 2      0.191245    0.105693    0.029791    (02:12)
# 3      0.164378    0.133760    0.034682    (02:12)
# 4      0.144011    0.088537    0.021343    (02:12)
# 5      0.089188    0.057160    0.014006    (02:12)
# 6      0.075289    0.041564    0.008226    (02:12)
# 7      0.064029    0.067838    0.007781    (02:12)
# 8      0.034890    0.097620    0.006003    (02:12)
# 9      0.018935    0.027544    0.004669    (02:12)
# 10     0.017735    0.035335    0.004446    (02:12)

# %% [markdown]
# Really good result for first cycles

# %%
learn.save('last-50-best-er')

# %%
learn.fit_one_cycle(5, max_lr=slice(1e-4,1e-3))
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, max=5), HTML(value='0.00% [0/5 00:00<00:00]'))), HTML(value…
# Total time: 11:02
# epoch  train loss  valid loss  error_rate
# 1      0.011344    0.064853    0.005558    (02:12)
# 2      0.012623    0.138295    0.005113    (02:12)
# 3      0.009628    0.023639    0.003779    (02:12)
# 4      0.016422    0.058537    0.004446    (02:12)
# 5      0.010218    0.017465    0.002890    (02:12)

# %% [markdown]
# Continue to improve

# %%
learn.save('last-50-best-er')

# %%
learn.fit_one_cycle(5, max_lr=slice(1e-4,1e-3))
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, max=5), HTML(value='0.00% [0/5 00:00<00:00]'))), HTML(value…
# Total time: 11:02
# epoch  train loss  valid loss  error_rate
# 1      0.012588    0.179811    0.006003    (02:12)
# 2      0.011053    0.020692    0.003112    (02:12)
# 3      0.007353    0.018512    0.002890    (02:12)
# 4      0.010158    0.017707    0.002446    (02:12)
# 5      0.006436    0.018385    0.002890    (02:12)

# %% [markdown]
# Better and better...

# %%
learn.save('last-50-best-er')

# %%
learn.fit_one_cycle(2, max_lr=slice(1e-4,1e-3))
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, max=2), HTML(value='0.00% [0/2 00:00<00:00]'))), HTML(value…
# Total time: 04:24
# epoch  train loss  valid loss  error_rate
# 1      0.006717    0.019600    0.002223    (02:11)
# 2      0.002628    0.053220    0.004002    (02:12)

# %% [markdown]
# **OVERFIT** Restore previous
#
# We're done!

# %%
learn.load('last-50-best-er')

# %% [markdown]
# ## Results

# %%
interp = ClassificationInterpretation.from_learner(learn)
# Out:
# HBox(children=(IntProgress(value=0, max=71), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=71), HTML(value='0.00% [0/71 00:00<00:00]')))

# %%
r = interp.most_confused(min_val=0)
print(r)
# Out:
# [('c8', 'c6', 7), ('c5', 'c0', 3), ('c8', 'c9', 2), ('c7', 'c2', 1), ('c4', 'c3', 1), ('c0', 'c1', 1), ('c3', 'c0', 1), ('c6', 'c2', 1), ('c9', 'c8', 1)]

# %%
number_of_errors = sum(map(lambda x: x[2], r))
number_of_test_items = interp.losses.size()[0]
e = number_of_errors/number_of_test_items
print(f'{number_of_errors}/{number_of_test_items} = {e}')
# Out:
# 18/4498 = 0.004001778568252557

# %% [markdown]
# **That's an incredible result!**

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=120)

# %% [markdown]
# ## Create submission

# %%
preds = learn.TTA(is_test=True, scale=1.0)[0]
# Out:
# HBox(children=(IntProgress(value=0, max=1246), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1246), HTML(value='0.00% [0/1246 00:00<00:00]')))
# VBox(children=(HBox(children=(IntProgress(value=0, max=8), HTML(value='0.00% [0/8 00:00<00:00]'))), HTML(value…
# Total time: 35:04

# %%
print('Images to test: ',np.shape(data.test_dl.dl.dataset.x)[0])
print('Predictions: ',np.shape(preds.numpy()))
# Out:
# Images to test:  79726
# Predictions:  (79726, 10)

# %%
# Find file name
preds_name = [(path.name) for path in data.test_dl.dl.dataset.x]
preds_name[:10]
# Out:
# ['img_44563.jpg',
#  'img_24158.jpg',
#  'img_69173.jpg',
#  'img_21453.jpg',
#  'img_12083.jpg',
#  'img_49408.jpg',
#  'img_80686.jpg',
#  'img_9258.jpg',
#  'img_98345.jpg',
#  'img_90161.jpg']

# %%
# Preds vals...
preds_val = preds.numpy()
preds_val[0,:]
# Out:
# array([ 0.47201967, -5.893962  ,  0.51600665, -7.381721  , -0.48315662,
#        -2.8100977 ,  1.1331651 ,  1.9703125 , 15.756922  , -4.518771  ],
#       dtype=float32)

# %%
# Sort classes
sorted_classes = sorted(data.classes)
sorted_classes
# Out:
# ['c0', 'c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8', 'c9']

# %%
# Find best prediction
preds_id = (preds.argmax(dim=1)).numpy()
preds_id[:15]
# Out:
# array([8, 4, 2, 8, 2, 6, 5, 2, 1, 4, 7, 8, 1, 6, 0])

# %%
# Get correct class
preds_classes = list(map(lambda id: data.classes[id], preds_id)) # Use original classes order
preds_classes[:10]
# Out:
# ['c6', 'c0', 'c4', 'c6', 'c4', 'c1', 'c3', 'c4', 'c5', 'c0']

# %% [markdown]
# ## Analyze predictions

# %%
df = pd.DataFrame({'name': preds_name, 'path':data.test_dl.dl.dataset.x, 'cls': preds_classes})
df['desc'] = df.cls.map(lambda c: description_dict[c])
df.head()
# Out:
#             name                                               path cls  \
# 0  img_44563.jpg  /home/ste/.fastai/data/distracted-driver/test/...  c6
# 1  img_24158.jpg  /home/ste/.fastai/data/distracted-driver/test/...  c0
# 2  img_69173.jpg  /home/ste/.fastai/data/distracted-driver/test/...  c4
# 3  img_21453.jpg  /home/ste/.fastai/data/distracted-driver/test/...  c6
# 4  img_12083.jpg  /home/ste/.fastai/data/distracted-driver/test/...  c4
#
#                           desc
# 0                     drinking
# 1                 safe driving
# 2  talking on the phone - left
# 3                     drinking
# 4  talking on the phone - left

# %%
import IPython
for index, row in df[0:3].iterrows():
    display(row['name'] + ' : ' + row.desc)
    display(IPython.display.Image(filename=row.path.as_posix()))
# Out:
# 'img_44563.jpg : drinking'
# 'img_24158.jpg : safe driving'
# 'img_69173.jpg : talking on the phone - left'

# %% [markdown]
# ## Softmax for probability

# %%
# Actual Preds:
preds_final = preds.numpy()
print(preds_final[:10])
# Out:
# [[ 0.47201967 -5.893962    0.51600665 -7.381721   -0.48315662 -2.8100977
#    1.1331651   1.9703125  15.756922   -4.518771  ]
#  [-1.3698689  -0.9610573  -5.008897    0.8450655   8.983259   -5.234997
#    0.05650663 -0.41009367 -4.031609   -1.2821112 ]
#  [-1.6863201  -6.8278008  11.519676    1.8596051  -5.0214653  -4.5217724
#   -6.509868   -3.5482006  -4.1288333   5.3786726 ]
#  [ 1.7408292  -2.578117    3.2785997  -2.7209074  -6.9732065  -3.4771082
#   -1.5067096   4.5707135  20.280247   -7.0989075 ]
#  [-6.6937666   1.0937588  17.2616     -6.953684   -4.2745047   4.956279
#   -6.9407425   0.3812453  -3.4118881  -0.5409039 ]
#  [-2.8605113  -9.352596   -0.44239894 -1.3485882   0.7704673  -1.7526598
#   12.720041    0.9801366  -3.0412698  -2.4092147 ]
#  [-7.496296    0.76552933 -1.7112901  -1.6594894  -0.47991672 14.799203
#   -4.806533   -1.4164331  -4.204503   -3.0869365 ]
#  [-4.596288    3.2954247  16.913103    0.6176839  -8.158709    3.8172848
#   -9.806824   -1.0009605  -3.15351    -5.0351143 ]
#  [ 0.9174477  10.970843   -4.5257792  -3.3670344  -0.7356359  -5.5519624
#   -7.9907284  -4.7941074   3.1937363   4.116235  ]
#  [-5.674423   -4.0578346  -3.8831522  -7.6430883  12.731587   -3.2881794
#   -6.7610006  -7.7783422  -6.6935244   5.497528  ]]

# %%
def softmax(x):
    '''
    Numpy Softmax, via comments on https://gist.github.com/stober/1946926
    >>> res = softmax(np.array([0, 200, 10]))
    >>> np.sum(res)
    1.0
    >>> np.all(np.abs(res - np.array([0, 1, 0])) < 0.0001)
    True
    >>> res = softmax(np.array([[0, 200, 10], [0, 10, 200], [200, 0, 10]]))
    >>> np.sum(res, axis=1)
    array([ 1.,  1.,  1.])
    >>> res = softmax(np.array([[0, 200, 10], [0, 10, 200]]))
    >>> np.sum(res, axis=1)
    array([ 1.,  1.])
    '''
    if x.ndim == 1:
        x = x.reshape((1, -1))
    max_x = np.max(x, axis=1).reshape((-1, 1))
    exp_x = np.exp(x - max_x)
    return exp_x / np.sum(exp_x, axis=1).reshape((-1, 1))

# %%
preds_softmax = softmax(preds_final)
print(preds_softmax[:10,:])
# Out:
# [[2.30064856e-07 3.95494304e-10 2.40410657e-07 8.93334365e-11
#   8.85162237e-08 8.63862404e-09 4.45638193e-07 1.02932052e-06
#   9.99997973e-01 1.56450863e-09]
#  [3.18728853e-05 4.79695882e-05 8.37551966e-07 2.91981385e-04
#   9.99373734e-01 6.68063592e-07 1.32705449e-04 8.32236474e-05
#   2.22557719e-06 3.47963905e-05]
#  [1.83546422e-06 1.07356746e-08 9.97785807e-01 6.36387485e-05
#   6.53598207e-08 1.07727040e-07 1.47538550e-08 2.85194801e-07
#   1.59579017e-07 2.14799540e-03]
#  [8.88041551e-09 1.18232937e-10 4.13311980e-08 1.02500418e-10
#   1.45873352e-12 4.81184745e-11 3.45179330e-10 1.50465212e-07
#   9.99999762e-01 1.28642453e-12]
#  [3.94742433e-11 9.51467314e-08 9.99995351e-01 3.04392241e-11
#   4.43594272e-10 4.52756467e-06 3.08357125e-11 4.66608441e-08
#   1.05103204e-09 1.85553386e-08]
#  [1.71176382e-07 2.59398475e-10 1.92139601e-06 7.76361560e-07
#   6.46187027e-06 5.18296019e-07 9.99981761e-01 7.96922996e-06
#   1.42870277e-07 2.68806360e-07]
#  [2.07581050e-10 8.03993544e-07 6.75435246e-08 7.11344654e-08
#   2.31399355e-07 9.99998689e-01 3.05728953e-09 9.07065143e-08
#   5.58206414e-09 1.70666379e-08]
#  [4.55604887e-10 1.21875348e-06 9.99996662e-01 8.37505567e-08
#   1.29255513e-11 2.05379388e-06 2.48703423e-12 1.65966032e-08
#   1.92832217e-09 2.93770952e-10]
#  [4.29737884e-05 9.98476207e-01 1.85883252e-07 5.92211336e-07
#   8.22770016e-06 6.66153284e-08 5.81342618e-09 1.42136827e-07
#   4.18584328e-04 1.05297740e-03]
#  [1.01404725e-08 5.10662197e-08 6.08130151e-08 1.41604617e-09
#   9.99278724e-01 1.10252870e-07 3.42107986e-09 1.23690791e-09
#   3.65988795e-09 7.21065269e-04]]

# %%
# With softmax
import pandas as pd
subm = pd.DataFrame({'img': preds_name})
for i,c in enumerate(data.classes):
    subm[c]=(preds_softmax[:,i]) # cast to int..
cols = ['img']+sorted_classes
subm = subm[cols]
subm.head(10)
# Out:
#              img            c0            c1            c2            c3  \
# 0  img_44563.jpg  8.851622e-08  4.456382e-07  1.029321e-06  8.638624e-09
# 1  img_24158.jpg  9.993737e-01  1.327054e-04  8.322365e-05  6.680636e-07
# 2  img_69173.jpg  6.535982e-08  1.475386e-08  2.851948e-07  1.077270e-07
# 3  img_21453.jpg  1.458734e-12  3.451793e-10  1.504652e-07  4.811847e-11
# 4  img_12083.jpg  4.435943e-10  3.083571e-11  4.666084e-08  4.527565e-06
# 5  img_49408.jpg  6.461870e-06  9.999818e-01  7.969230e-06  5.182960e-07
# 6  img_80686.jpg  2.313994e-07  3.057290e-09  9.070651e-08  9.999987e-01
# 7   img_9258.jpg  1.292555e-11  2.487034e-12  1.659660e-08  2.053794e-06
# 8  img_98345.jpg  8.227700e-06  5.813426e-09  1.421368e-07  6.661533e-08
# 9  img_90161.jpg  9.992787e-01  3.421080e-09  1.236908e-09  1.102529e-07
#
#              c4            c5            c6            c7            c8  \
# 0  2.404107e-07  3.954943e-10  9.999980e-01  2.300649e-07  8.933344e-11
# 1  8.375520e-07  4.796959e-05  2.225577e-06  3.187289e-05  2.919814e-04
# 2  9.977858e-01  1.073567e-08  1.595790e-07  1.835464e-06  6.363875e-05
# 3  4.133120e-08  1.182329e-10  9.999998e-01  8.880416e-09  1.025004e-10
# 4  9.999954e-01  9.514673e-08  1.051032e-09  3.947424e-11  3.043922e-11
# 5  1.921396e-06  2.593985e-10  1.428703e-07  1.711764e-07  7.763616e-07
# 6  6.754352e-08  8.039935e-07  5.582064e-09  2.075810e-10  7.113447e-08
# 7  9.999967e-01  1.218753e-06  1.928322e-09  4.556049e-10  8.375056e-08
# 8  1.858833e-07  9.984762e-01  4.185843e-04  4.297379e-05  5.922113e-07
# 9  6.081302e-08  5.106622e-08  3.659888e-09  1.014047e-08  1.416046e-09
#
#              c9
# 0  1.564509e-09
# 1  3.479639e-05
# 2  2.147995e-03
# 3  1.286425e-12
# 4  1.855534e-08
# 5  2.688064e-07
# 6  1.706664e-08
# 7  2.937710e-10
# 8  1.052977e-03
# 9  7.210653e-04

# %%
subm_file_name = (path/'submission.csv').as_posix()
print(subm_file_name)
# Out:
# /home/ste/.fastai/data/distracted-driver/submission.csv

# %%
# Create submission
subm.to_csv(subm_file_name + '.gz', index=False, compression='gzip')

# %%
# Submit to kaggle
# !kaggle competitions submit -f {subm_file_name} -m "Submission reviewed" {competition_name}
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.0 / client 1.4.7.1)
# Successfully submitted to State Farm Distracted Driver Detection
